# %% [markdown]
# <a href="https://colab.research.google.com/github/amadousysada/ecommerce-customer-segmentation/blob/main/maintenance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
t_init = time.time()
import pandas as pd

# %%
folder_path = "/content/drive/MyDrive/data/" # A ajuster selon le chemin où se trouve votre fichier .db

# %% [markdown]
# # 1 | Préparation des données

# %%
data = pd.read_csv(folder_path + "olist_customer_cleaned_data.csv")

# %%
data
# Out:
#                      customer_unique_id  recency  frequency  monetary  \
# 0      0000366f3b9a7992bf8c76cfdf3221e2      111        0.0  4.955123
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f      114        0.0  3.302849
# 2      0000f46a3911fa3c0805444483337064      536        0.0  4.456902
# 3      0000f6ccb0745a6a4b88665a16c9f078      320        0.0  3.775516
# 4      0004aac84e0df4da2b147fca70cf8255      287        0.0  5.282645
# ...                                 ...      ...        ...       ...
# 89392  fffbf87b7a1a6fa8b03f081c5f51a201      244        0.0  5.119908
# 89393  fffea47cd6d3cc0a88bd621562a9d061      261        0.0  4.437698
# 89394  ffff371b4d645b6ecea244b27531430a      567        0.0  4.722598
# 89395  ffff5962728ec6157033ef9805bacc48      118        0.0  4.895524
# 89396  ffffd2657e2aad2907e67c3e9daecbeb      483        0.0  4.270536
#
#        rfm_score  rfm_segment  satisfaction  nbre_items  distinct_products  \
# 0              8          413           5.0         1.0                1.0
# 1              6          411           4.0         1.0                1.0
# 2              4          112           3.0         1.0                1.0
# 3              4          211           4.0         1.0                1.0
# 4              7          214           5.0         1.0                1.0
# ...          ...          ...           ...         ...                ...
# 89392          6          213           5.0         1.0                1.0
# 89393          5          212           4.0         1.0                1.0
# 89394          5          113           5.0         1.0                1.0
# 89395          7          313           5.0         1.0                1.0
# 89396          4          112           5.0         1.0                1.0
#
#             first_purch_at        last_purch_at  last_purch_day_of_week  \
# 0      2018-05-10 10:56:27  2018-05-10 10:56:27                       3
# 1      2018-05-07 11:11:27  2018-05-07 11:11:27                       0
# 2      2017-03-10 21:05:03  2017-03-10 21:05:03                       4
# 3      2017-10-12 20:29:41  2017-10-12 20:29:41                       3
# 4      2017-11-14 19:45:42  2017-11-14 19:45:42                       1
# ...                    ...                  ...                     ...
# 89392  2017-12-27 22:36:41  2017-12-27 22:36:41                       2
# 89393  2017-12-10 20:07:56  2017-12-10 20:07:56                       6
# 89394  2017-02-07 15:49:16  2017-02-07 15:49:16                       1
# 89395  2018-05-02 15:17:41  2018-05-02 15:17:41                       2
# 89396  2017-05-02 20:18:45  2017-05-02 20:18:45                       1
#
#        customer_zip_code_prefix rfm_segment_loyalty
# 0                          7787          top (Gold)
# 1                          6053       risk (bronze)
# 2                         88115            inactive
# 3                         66812            inactive
# 4                         18040       good (silver)
# ...                         ...                 ...
# 89392                     60055       risk (bronze)
# 89393                     44054            inactive
# 89394                     78552            inactive
# 89395                     29460       good (silver)
# 89396                     83608            inactive
#
# [89397 rows x 14 columns]

# %%
data.describe()
# Out:
#             recency  frequency      monetary     rfm_score   rfm_segment  \
# count  89397.000000    89397.0  89397.000000  89397.000000  89397.000000
# mean     237.413358        0.0      4.660908      5.929886    263.893341
# std      152.762223        0.0      0.757972      1.578280    111.731636
# min        0.000000        0.0      2.516890      3.000000    111.000000
# 25%      114.000000        0.0      4.122122      5.000000    211.000000
# 50%      218.000000        0.0      4.646216      6.000000    311.000000
# 75%      346.000000        0.0      5.154043      7.000000    411.000000
# max      694.000000        0.0      6.858155      9.000000    414.000000
#
#        satisfaction    nbre_items  distinct_products  last_purch_day_of_week  \
# count  89397.000000  89397.000000       89397.000000            89397.000000
# mean       4.127969      1.132208           1.035784                2.755115
# std        1.321565      0.493916           0.215940                1.967398
# min        0.000000      1.000000           1.000000                0.000000
# 25%        4.000000      1.000000           1.000000                1.000000
# 50%        5.000000      1.000000           1.000000                3.000000
# 75%        5.000000      1.000000           1.000000                4.000000
# max        5.000000     21.000000           7.000000                6.000000
#
#        customer_zip_code_prefix
# count              89397.000000
# mean               35210.199157
# std                29838.239458
# min                 1003.000000
# 25%                11370.000000
# 50%                24451.000000
# 75%                59063.000000
# max                99980.000000

# %% [markdown]
# # 2 | Standardisation des données

# %%
num_cols = ['recency', 'frequency', 'monetary', 'satisfaction', 'nbre_items', 'distinct_products']
ss = StandardScaler()
X_scaled = data.copy()

# %%
X_scaled[num_cols] = ss.fit_transform(X_scaled[num_cols])
X_scaled.head()
# Out:
#     recency  frequency  monetary  satisfaction  nbre_items  distinct_products  \
# 0 -0.827522        0.0  0.388162      0.659852   -0.267675          -0.165715
# 1 -0.807883        0.0 -1.791711     -0.096832   -0.267675          -0.165715
# 2  1.954595        0.0 -0.269149     -0.853515   -0.267675          -0.165715
# 3  0.540625        0.0 -1.168114     -0.096832   -0.267675          -0.165715
# 4  0.324602        0.0  0.820269      0.659852   -0.267675          -0.165715
#
#                  customer_unique_id
# 0  0000366f3b9a7992bf8c76cfdf3221e2
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f
# 2  0000f46a3911fa3c0805444483337064
# 3  0000f6ccb0745a6a4b88665a16c9f078
# 4  0004aac84e0df4da2b147fca70cf8255

# %%
rfm_feats = ['recency', 'frequency', 'monetary']

# %%
t_final = time.time()
print(f"La durée d'execution compléte du notebook est de: {t_final - t_init} secondes")

# %% [markdown]
# # FIN
